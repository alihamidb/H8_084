# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
X= -2 * np.random.rand(100,2)
X1 = 1 + 2 * np.random.rand(50,2)
X[50:100, :] = X1

plt.scatter(X[ : , 0], X[ :, 1], s = 50, c = 'b')
plt.show()

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()
# Out:
# C:\Users\ali.hamid\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
Kmean = KMeans(n_clusters=2)
Kmean.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
Kmean.cluster_centers_
# Out:
# array([[ 2.18487446,  1.94890555],
#        [-0.9894006 , -0.88964281]])

# %%
plt.scatter(X[ : , 0], X[ : , 1], s =50, c='b')
plt.scatter(2.18487446,  1.94890555, s=300, c='c', marker='h')
plt.scatter(-0.9894006 , -0.88964281, s=300, c='y', marker='h')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans

# %%
data=pd.read_csv('https://github.com/alihamidb/H8_084/blob/4d2d3a4a30bf3feef5e67e055814eeb3f63c9953/wholesale_customers_data.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 data=pd.read_csv('https://github.com/alihamidb/H8_084/blob/4d2d3a4a30bf3feef5e67e055814eeb3f63c9953/wholesale_customers_data.csv')
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
data.describe()
